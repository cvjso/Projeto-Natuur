# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/dados_projeto.csv')

# %%
data
# Out:
#            Hora de saida                       Cliente  \
# 0    2019-07-02 14:19:17  Sônia Fernanda Carvalho Neto
# 1    1991-05-01 00:02:32    Srta. Samara Adriele Neves
# 2    1992-04-24 00:11:29  Dr. Teobaldo Santacruz Filho
# 3    1987-12-14 11:28:15     Sra. Andressa Lozano Neto
# 4    2017-07-09 06:37:54         Rodolfo Vicente Gomes
# ..                   ...                           ...
# 995  1995-01-05 22:48:44         Srta. Karine Delvalle
# 996  1987-04-26 02:21:55         Gabriela Márcia Urias
# 997  1987-05-01 19:52:56       Dr. Raysa Azevedo Filho
# 998  2021-09-13 03:42:15          Yasmin Domingues Jr.
# 999  2013-10-22 16:00:48            Letícia Montenegro
#
#                                  Artesão   Preço      Produto  \
# 0             Srta. Ornela Marisa Padrão  272953     deserunt
# 1               Dr. Mateus Vega Sobrinho      60  consectetur
# 2                          Wilson Corona      48       cumque
# 3      Srta. Gabrielle Rocha Azevedo Jr.     682          sit
# 4    Sr. Hernani Fabrício Serra Sobrinho    8646  consequatur
# ..                                   ...     ...          ...
# 995      Dr. Augusto Carvalho de Freitas  587781         sunt
# 996                         Marcos Serra      29        optio
# 997      Sr. Rodrigo Branco Meireles Jr.   89846     deleniti
# 998               William Martines Gomes    4670        ullam
# 999                      Dr. Gean Corona   87187          est
#
#          Hora de chegada  Cartão  Espécie  Quantidade
# 0    2016-11-13 22:44:39     NaN      1.0       55573
# 1    2001-04-19 05:02:36     1.0      1.0        7469
# 2    1987-06-01 23:20:08     1.0      1.0   381596740
# 3    2019-06-21 12:22:52     1.0      1.0    46528148
# 4    1975-01-28 14:37:58     NaN      NaN       72777
# ..                   ...     ...      ...         ...
# 995  2015-10-12 16:21:34     NaN      1.0          91
# 996  2013-11-21 16:56:38     1.0      NaN    11344007
# 997  2004-06-28 20:32:49     1.0      1.0      732361
# 998  1991-09-01 09:02:29     1.0      1.0           0
# 999  1973-11-27 21:15:30     NaN      NaN          64
#
# [1000 rows x 9 columns]

# %%
# Limpando o dataframe

# %%
data[data['Hora de saida'] == '2021-02-29']
# Out:
#     Hora de saida  Preço                   Produto Hora de chegada  Cartão  \
# 233    2021-02-29      5  Banco de Madeira de Onça      2021-10-08     NaN
#
#      Espécie  Quantidade  Compra
# 233      NaN           6      30

# %%
data.loc[233, 'Hora de saida'] = '2021-03-01'

# %%
pd.options.mode.chained_assignment = None  # default='warn'

data['Hora de saida'] = data['Hora de saida'].str[4:]
data['Hora de saida'] = '2021' + data['Hora de saida']

data['Hora de chegada'] = data['Hora de chegada'].str[4:]
data['Hora de chegada'] = '2021' + data['Hora de chegada']

data['Preço'] = data['Preço'] % 1000

data['Quantidade'] = data['Quantidade'] % 10
for i in range(0, 1000):
    if data['Quantidade'][i] == 0:
        data['Quantidade'][i] = 1

# %%
data.head()
# Out:
#          Hora de saida                       Cliente  \
# 0  2021-07-02 14:19:17  Sônia Fernanda Carvalho Neto
# 1  2021-05-01 00:02:32    Srta. Samara Adriele Neves
# 2  2021-04-24 00:11:29  Dr. Teobaldo Santacruz Filho
# 3  2021-12-14 11:28:15     Sra. Andressa Lozano Neto
# 4  2021-07-09 06:37:54         Rodolfo Vicente Gomes
#
#                                Artesão  Preço      Produto  \
# 0           Srta. Ornela Marisa Padrão    953     deserunt
# 1             Dr. Mateus Vega Sobrinho     60  consectetur
# 2                        Wilson Corona     48       cumque
# 3    Srta. Gabrielle Rocha Azevedo Jr.    682          sit
# 4  Sr. Hernani Fabrício Serra Sobrinho    646  consequatur
#
#        Hora de chegada  Cartão  Espécie  Quantidade
# 0  2021-11-13 22:44:39     NaN      1.0           3
# 1  2021-04-19 05:02:36     1.0      1.0           9
# 2  2021-06-01 23:20:08     1.0      1.0           1
# 3  2021-06-21 12:22:52     1.0      1.0           8
# 4  2021-01-28 14:37:58     NaN      NaN           7

# %%
# Tirando colunas que não são válidas para a análise e/ou comprometem de alguma forma a integridade dos envolvidos

# %%
data.drop('Cliente', inplace=True, axis=1)
data.drop('Artesão', inplace=True, axis=1)
data.head()
# Out:
#          Hora de saida  Preço      Produto      Hora de chegada  Cartão  \
# 0  2021-07-02 14:19:17    953     deserunt  2021-11-13 22:44:39     NaN
# 1  2021-05-01 00:02:32     60  consectetur  2021-04-19 05:02:36     1.0
# 2  2021-04-24 00:11:29     48       cumque  2021-06-01 23:20:08     1.0
# 3  2021-12-14 11:28:15    682          sit  2021-06-21 12:22:52     1.0
# 4  2021-07-09 06:37:54    646  consequatur  2021-01-28 14:37:58     NaN
#
#    Espécie  Quantidade
# 0      1.0           3
# 1      1.0           9
# 2      1.0           1
# 3      1.0           8
# 4      NaN           7

# %%
# Analíse mais básica do dataframe para poder melhor visualizar nossas opções

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hora de saida    1000 non-null   object
#  1   Preço            1000 non-null   int64
#  2   Produto          1000 non-null   object
#  3   Hora de chegada  1000 non-null   object
#  4   Cartão           517 non-null    float64
#  5   Espécie          505 non-null    float64
#  6   Quantidade       1000 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 54.8+ KB

# %%
data.describe()
# Out:
#              Preço  Cartão  Espécie   Quantidade
# count  1000.000000   517.0    505.0  1000.000000
# mean    375.793000     1.0      1.0     4.643000
# std     321.544437     0.0      0.0     2.709777
# min       0.000000     1.0      1.0     1.000000
# 25%      60.750000     1.0      1.0     2.000000
# 50%     324.500000     1.0      1.0     4.000000
# 75%     661.250000     1.0      1.0     7.000000
# max     999.000000     1.0      1.0     9.000000

# %%
data.sort_values(by=['Preço', 'Quantidade'], ascending=[False, False]).head()
# Out:
#            Hora de saida  Preço  Produto      Hora de chegada  Cartão  \
# 263  2021-04-09 22:46:56    999    totam  2021-01-28 08:40:38     1.0
# 938  2021-01-27 15:59:52    997    eaque  2021-04-26 05:25:19     1.0
# 180  2021-06-15 07:31:53    997     enim  2021-02-22 20:11:33     1.0
# 309  2021-05-17 08:07:28    997  impedit  2021-10-10 01:17:29     NaN
# 843  2021-05-02 02:37:15    997  ratione  2021-03-10 22:22:36     NaN
#
#      Espécie  Quantidade
# 263      1.0           9
# 938      NaN           5
# 180      NaN           2
# 309      NaN           1
# 843      1.0           1

# %%
lista_produtos = [ "Banco de Madeira de Onça", "Assadeira de Barro", "Cabeça em Cerâmica", "Arara Azul em Madeira", "Almofada de Tricô", "Peneira de Palha", "Beatas", "Banco de Madeira de Tatu", "Fruteira com 4 Carrancas"]

# %%
import random

for i in range(len(data["Produto"])):
    rand = random.randint(0,len(lista_produtos) - 1)
    data["Produto"][i] = lista_produtos[rand]

data["Produto"]
# Out:
# 0         Arara Azul em Madeira
# 1                        Beatas
# 2            Assadeira de Barro
# 3                        Beatas
# 4                        Beatas
#                  ...
# 995    Banco de Madeira de Tatu
# 996    Banco de Madeira de Onça
# 997          Cabeça em Cerâmica
# 998          Cabeça em Cerâmica
# 999       Arara Azul em Madeira
# Name: Produto, Length: 1000, dtype: object

# %%
data.head()
# Out:
#          Hora de saida  Preço                Produto      Hora de chegada  \
# 0  2021-07-02 14:19:17    953  Arara Azul em Madeira  2021-11-13 22:44:39
# 1  2021-05-01 00:02:32     60                 Beatas  2021-04-19 05:02:36
# 2  2021-04-24 00:11:29     48     Assadeira de Barro  2021-06-01 23:20:08
# 3  2021-12-14 11:28:15    682                 Beatas  2021-06-21 12:22:52
# 4  2021-07-09 06:37:54    646                 Beatas  2021-01-28 14:37:58
#
#    Cartão  Espécie  Quantidade
# 0     NaN      1.0           3
# 1     1.0      1.0           9
# 2     1.0      1.0           1
# 3     1.0      1.0           8
# 4     NaN      NaN           7

# %%
# data.to_csv('result.csv')

# %%
data.Produto.value_counts().sort_index(ascending=False).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
y = [] 
y.append(int(data['Cartão'].value_counts()))
y.append(int(data['Espécie'].value_counts()))
x = ['Cartão','Espécie']
plt.bar(x, y, color ='maroon',
        width = 0.4)
# Out:
# <BarContainer object of 2 artists>

# %%
data['Hora de saida'] = data['Hora de saida'].str[:10]

data['Hora de chegada'] = data['Hora de chegada'].str[:10]

data.head()
# Out:
#   Hora de saida  Preço                Produto Hora de chegada  Cartão  \
# 0    2021-07-02    953  Arara Azul em Madeira      2021-11-13     NaN
# 1    2021-05-01     60                 Beatas      2021-04-19     1.0
# 2    2021-04-24     48     Assadeira de Barro      2021-06-01     1.0
# 3    2021-12-14    682                 Beatas      2021-06-21     1.0
# 4    2021-07-09    646                 Beatas      2021-01-28     NaN
#
#    Espécie  Quantidade
# 0      1.0           3
# 1      1.0           9
# 2      1.0           1
# 3      1.0           8
# 4      NaN           7

# %%
data['Compra'] = data.Preço * data.Quantidade

# %%
data.head()
# Out:
#   Hora de saida  Preço                Produto Hora de chegada  Cartão  \
# 0    2021-07-02    953  Arara Azul em Madeira      2021-11-13     NaN
# 1    2021-05-01     60                 Beatas      2021-04-19     1.0
# 2    2021-04-24     48     Assadeira de Barro      2021-06-01     1.0
# 3    2021-12-14    682                 Beatas      2021-06-21     1.0
# 4    2021-07-09    646                 Beatas      2021-01-28     NaN
#
#    Espécie  Quantidade  Compra
# 0      1.0           3    2859
# 1      1.0           9     540
# 2      1.0           1      48
# 3      1.0           8    5456
# 4      NaN           7    4522

# %%
aux = data.groupby(['Produto']).sum()
aux = aux.sort_values(['Compra'], ascending=False)

# %%
plt.plot(aux.drop(['Preço', 'Cartão', 'Espécie', 'Quantidade'], axis=1)[0:3])

# %%
import datetime

# %%
chegada = data['Hora de chegada']
chegada = pd.to_datetime(chegada)
saida = data['Hora de saida']
saida = pd.to_datetime(saida)

# %%
res = chegada - saida
res = res.dt.days

# %%
res = res.abs()

# %%
data['Periodo'] = res
data
# Out:
#     Hora de saida  Preço                   Produto Hora de chegada  Cartão  \
# 0      2021-07-02    953     Arara Azul em Madeira      2021-11-13     NaN
# 1      2021-05-01     60                    Beatas      2021-04-19     1.0
# 2      2021-04-24     48        Assadeira de Barro      2021-06-01     1.0
# 3      2021-12-14    682                    Beatas      2021-06-21     1.0
# 4      2021-07-09    646                    Beatas      2021-01-28     NaN
# ..            ...    ...                       ...             ...     ...
# 995    2021-01-05    781  Banco de Madeira de Tatu      2021-10-12     NaN
# 996    2021-04-26     29  Banco de Madeira de Onça      2021-11-21     1.0
# 997    2021-05-01    846        Cabeça em Cerâmica      2021-06-28     1.0
# 998    2021-09-13    670        Cabeça em Cerâmica      2021-09-01     1.0
# 999    2021-10-22    187     Arara Azul em Madeira      2021-11-27     NaN
#
#      Espécie  Quantidade  Compra  Periodo
# 0        1.0           3    2859      134
# 1        1.0           9     540       12
# 2        1.0           1      48       38
# 3        1.0           8    5456      176
# 4        NaN           7    4522      162
# ..       ...         ...     ...      ...
# 995      1.0           1     781      280
# 996      NaN           7     203      209
# 997      1.0           1     846       58
# 998      1.0           1     670       12
# 999      NaN           4     748       36
#
# [1000 rows x 9 columns]

# %%
tempo = data.groupby(['Produto']).sum()
periodo = tempo['Periodo'].sort_index(ascending=False).values
periodo
# Out:
# array([14392, 11982, 15417, 14032, 13214, 11004, 14000, 12134, 11685])

# %%
count = data.Produto.value_counts().sort_index(ascending=False).values
count
# Out:
# array([127, 108, 120, 120, 110,  96, 119, 103,  97])

# %%
media = []

for i in range(len(periodo)):
    media.append(periodo[i]/count[i])

media
# Out:
# [113.32283464566929,
#  110.94444444444444,
#  128.475,
#  116.93333333333334,
#  120.12727272727273,
#  114.625,
#  117.6470588235294,
#  117.80582524271844,
#  120.4639175257732]

# %%
eixo_x = tempo['Periodo'].sort_index(ascending=False).index
eixo_x
# Out:
# Index(['Peneira de Palha', 'Fruteira com 4 Carrancas', 'Cabeça em Cerâmica',
#        'Beatas', 'Banco de Madeira de Tatu', 'Banco de Madeira de Onça',
#        'Assadeira de Barro', 'Arara Azul em Madeira', 'Almofada de Tricô'],
#       dtype='object', name='Produto')

# %%
eixo_y = media
eixo_y
# Out:
# [113.32283464566929,
#  110.94444444444444,
#  128.475,
#  116.93333333333334,
#  120.12727272727273,
#  114.625,
#  117.6470588235294,
#  117.80582524271844,
#  120.4639175257732]

# %%
plt.bar(eixo_x, height=eixo_y)
# Out:
# <BarContainer object of 9 artists>

# %%
data.to_csv('result.csv')

# %%
data
# Out:
#     Hora de saida  Preço                   Produto Hora de chegada  Cartão  \
# 0      2021-07-02    953     Arara Azul em Madeira      2021-11-13     NaN
# 1      2021-05-01     60                    Beatas      2021-04-19     1.0
# 2      2021-04-24     48        Assadeira de Barro      2021-06-01     1.0
# 3      2021-12-14    682                    Beatas      2021-06-21     1.0
# 4      2021-07-09    646                    Beatas      2021-01-28     NaN
# ..            ...    ...                       ...             ...     ...
# 995    2021-01-05    781  Banco de Madeira de Tatu      2021-10-12     NaN
# 996    2021-04-26     29  Banco de Madeira de Onça      2021-11-21     1.0
# 997    2021-05-01    846        Cabeça em Cerâmica      2021-06-28     1.0
# 998    2021-09-13    670        Cabeça em Cerâmica      2021-09-01     1.0
# 999    2021-10-22    187     Arara Azul em Madeira      2021-11-27     NaN
#
#      Espécie  Quantidade  Compra  Periodo
# 0        1.0           3    2859      134
# 1        1.0           9     540       12
# 2        1.0           1      48       38
# 3        1.0           8    5456      176
# 4        NaN           7    4522      162
# ..       ...         ...     ...      ...
# 995      1.0           1     781      280
# 996      NaN           7     203      209
# 997      1.0           1     846       58
# 998      1.0           1     670       12
# 999      NaN           4     748       36
#
# [1000 rows x 9 columns]
